# %%
import pandas as pd
import matplotlib.pyplot as plt

LAST_FR="/data/prevel/runs/158_01:12/parents_gen51.csv"
df=pd.read_csv(LAST_FR)

# %%
LAST_FR="/data/prevel/runs/6dofs_anklerms_enerfy_anklecor_striketolift_p1/parents_gen51.csv"
df=pd.read_csv(LAST_FR)
plt.scatter(df.fit_rmsankle,df.fit_energy)
plt.xlabel("RMS error ankle")
plt.ylabel("Energy")
# Out:
# Text(0, 0.5, 'Energy')

# %%
plt.scatter(df.fit_rmsankle,df.fit_rmsknee)
plt.xlabel("RMS error ankle")
plt.ylabel("RMS error knee")
# Out:
# Text(0, 0.5, 'RMS error knee')
