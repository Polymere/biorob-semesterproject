# %%
import pandas as pd
RAW_DATA_PATH="../../data/default_name.csv"
#RAW_REFERENCE_PATH="../../data/raw_reference.csv"
TIME_STEP=1.0 #ms
import matplotlib.pyplot as plt

data_in=pd.read_csv(open(RAW_DATA_PATH))
#data_ref=pd.read_csv(open(RAW_REFERENCE_PATH))
def preprocess(data_in):
    data_out=pd.DataFrame(data_in.index)
    data_out["time"]=data_in.index*TIME_STEP
    data_out.set_index(data_out["time"],inplace=True)
    activation=data_in.filter(like="act",axis=1)
    data_out["energy"]=activation.sum(axis=1,skipna=True)
    return data_out
trial=preprocess(data_in)
#ref=preprocess(data_ref)

# %%
plt.plot(trial["energy"][0:200])
#plt.plot(ref["energy"][0:200])

# %%
plt.plot(data_in.angles_trunk)

# %%
plt.plot(data_in.LGRF_GRFx[0:200])
plt.plot(data_ref.LGRF_GRFx[0:200])

# %%
plt.plot(data_in.velocities_ankle_l)

# %%
#print(data_in.columns)
# Out:
#            LGRF_GRFx    LGRF_GRFy\n  moments_ankle_l  moments_ankle_r  \
# time
# 0.0    3.834637e-238 -1.539135e-236         0.000000         0.000000
# 1.0    2.853467e-224  2.443837e-224         1.654421         1.654421
# 2.0    7.980527e-227 -2.257887e-226        -0.132071        -0.132071
# 3.0   -3.920480e-224 -3.817982e-224        -2.686558        -2.686558
# 4.0   -1.494041e-224 -1.975321e-224        -0.572994        -0.572994
# 5.0    9.349730e-224  7.269861e-224         4.580777         4.580777
# 6.0   -2.079792e-280   1.097726e+02        12.755415        12.763557
# 7.0   -7.841094e-250   1.801281e+02        24.283660        24.530426
# 8.0   -1.964460e-244   2.685486e+02        36.321563        36.975484
# 9.0    3.765782e-190   3.666181e+02        52.687934        55.076413
# 10.0    4.162122e+02   1.706490e+03        70.694005        75.636628
# 11.0    5.822802e+02   1.997038e+03        81.342696        88.779131
# ...

# %%
reshaped_in.set_index(data_out["time"],inplace=True)
reshaped_in

# %%
for field in data_in.columns:
    print (field)
# Out:
# LGRF_GRFx
# LGRF_GRFy
#
# moments_ankle_l
# moments_ankle_r
# moments_hip_l
# moments_hip_r
# moments_knee_l
# moments_knee_r
# stim_bifemlh_l
# stim_bifemlh_r
# stim_glut_max_l
# stim_glut_max_r
# stim_med_gas_l
# stim_med_gas_r
# stim_psoas_l
# stim_psoas_r
# stim_soleus_l
# stim_soleus_r
# stim_tib_ant_l
# stim_tib_ant_r
# stim_vas_int_l
# stim_vas_int_r
# RGRF_GRFx
# RGRF_GRFy
#
# f_ce_bifemlh_l
# f_ce_bifemlh_r
# f_ce_glut_max_l
# f_ce_glut_max_r
# f_ce_med_gas_l
# f_ce_med_gas_r
# f_ce_psoas_l
# f_ce_psoas_r
# f_ce_soleus_l
# f_ce_soleus_r
# f_ce_tib_ant_l
# f_ce_tib_ant_r
# f_ce_vas_int_l
# f_ce_vas_int_r
# act_bifemlh_l
# act_bifemlh_r
# act_glut_max_l
# act_glut_max_r
# act_med_gas_l
# act_med_gas_r
# act_psoas_l
# act_psoas_r
# act_soleus_l
# act_soleus_r
# act_tib_ant_l
# act_tib_ant_r
# act_vas_int_l
# act_vas_int_r
# v_ce_bifemlh_l
# v_ce_bifemlh_r
# v_ce_glut_max_l
# v_ce_glut_max_r
# v_ce_med_gas_l
# v_ce_med_gas_r
# v_ce_psoas_l
# v_ce_psoas_r
# v_ce_soleus_l
# ...

# %%
import time
n=time.strftime("%j_%H:%M")
print(n)
# Out:
# 077_14:09

# %%
field="stim_vas_int_r"
field[-2:]
# Out:
# '_r'
