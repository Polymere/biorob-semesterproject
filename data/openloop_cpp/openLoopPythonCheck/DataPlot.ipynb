# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np 

df = pd.read_csv(r'{}muscles_activity1'.format('./'),sep=' ')
muscle_activity = df.values
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-1-77944b0b4675> in <module>
#       3 import numpy as np
#       4
# ----> 5 df = pd.read_csv(r'{}muscles_activity1'.format('./'),sep=' ')
#       6 muscle_activity = df.values
#       7
#
# ...

# %%
plt.plot(muscle_activity)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ...
